# %%
import pandas as pd
import numpy as np
import pickle
import time
import datetime
from dateutil.relativedelta import relativedelta
import requests
import locale
from pandas.io.json import json_normalize
import io
import os
from os.path import exists
import sys
from matplotlib import pyplot as plt
import numpy as np
from tqdm import tqdm

import matplotlib.pyplot as plt
import source.read_tickers_and_isins as URTI
import source.get_directors_dealings as UGDD
import source.get_timeseries as UGT
import source.analyze_get_summary_of_data as AGSOD
import source.preprocess_directors_dealings as UPDD
import source.preprocess_timeseries as UPTS
import source.preprocess_timeseries_from_excel as UPTFE
import source.analyse_single_company as UASC
import source.calculate_daily_returns_for_period as CDRFP
from source import data_checks, determine_T0_T1_T2, cut_timeseries, calculate_coefficients
import logging
logging.getLogger().setLevel(logging.WARNING)

# %% [markdown]
# ### Load return series

# %%
NAME = "Knudsen" # "Niedermayer"
DATA_LOCATION = f'data/{NAME}/'
DATA_LOCATION_INSIDER_RAW = DATA_LOCATION + 'raw/insider/'
DATA_LOCATION_INSIDER_PROCESSED = DATA_LOCATION + 'processed/insider/'
DATA_LOCATION_TIME_SERIES_RAW = DATA_LOCATION + 'raw/timeseries/'
DATA_LOCATION_TIME_SERIES_PROCESSED = DATA_LOCATION + 'processed/timeseries/'
DATA_LOCATION_RI = DATA_LOCATION + 'processed/RI/'

_ri_location = DATA_LOCATION_RI
_insider_location = DATA_LOCATION_INSIDER_PROCESSED


file_locs_ = os.listdir(_ri_location)
file_locs = [_ri_location + f for f in file_locs_]

companies = []
print("loading return series...")
for file_loc in tqdm(file_locs):
    with open(file_loc, "rb") as f:
        company = pickle.load(f)
    companies.append(company)
# Out:
# loading return series...
# 100%|██████████| 4077/4077 [00:29<00:00, 138.74it/s]

# %% [markdown]
# ### Calculate Returns, Analyse Companies

# %%
print("calculate returns")
returns_df = [CDRFP.calculate_daily_returns(c.return_index_df) for c in companies]

print("concatenate")
df_returns = pd.concat(returns_df[:10000], axis=1) # TODO remove the slice
df_return_index = pd.concat([c.return_index_df for c in companies[:10]], axis=1) # TODO remove the slice

print("analyse ...")
pickles = os.listdir(DATA_LOCATION_RI)[:100] # TODO remove
ISINs = [rick[:-7] for rick in pickles]

outputs = []
for isin in tqdm(ISINs):
    outputs.append(UASC.analyse_single_company(isin, DATA_LOCATION_RI, DATA_LOCATION_INSIDER_PROCESSED))
# Out:
# calculate returns
# concatenate
# analyse ...
# 100%|██████████| 100/100 [00:03<00:00, 25.27it/s]

# %% [markdown]
# ### Visualise Mean Daily Returns

# %%
plt.rc('font', family='serif')
plt.rc('xtick')
plt.rc('ytick')

fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)

returns_companies = df_returns.mean(axis=1)
returns_companies.plot(color="k", linewidth=0.7)

ax.set_xlabel('Time (Years)')
ax.set_ylabel('Mean Daily Return')
ax.set_title('Mean Daily Returns Over Time')

interval_borders = ["2020-02-01"] # TODO see if it makes sense to actually take first of Feb

for int_ in interval_borders:
    plt.axvline(x = int_, color = 'red', label = 'DD Event time', linewidth = 1)

plt.savefig(DATA_LOCATION +"visualisations/NYSE_daily_returns.jpg", dpi=600)
plt.show()

# %% [markdown]
# ### Investigate Filing Trade Lag Times

# %%
sum_returns = sum([x[0] for x in outputs], [])
filing_trade_lags = sum([x[1] for x in outputs], [])

lag_in_hours = np.asarray(filing_trade_lags)
negative_lag_mask = lag_in_hours < 0
positive_lag = lag_in_hours[~negative_lag_mask]
in_21_days = positive_lag < 21*24
relevant_lag = positive_lag[in_21_days]
print(f"Negative lag for {negative_lag_mask.sum()} out of {len(negative_lag_mask)} trades.")
print(f"Lag longer than 21 days for {len(positive_lag) - len(relevant_lag)} out of {len(negative_lag_mask)} trades.")
print(f"Eligible trades: {len(relevant_lag)} out of {len(negative_lag_mask)} trades.")

fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)
plt.hist(np.log(positive_lag), bins="auto")
ax.set_xlabel('Time (Log(Hours))')
ax.set_ylabel('Trades')
ax.set_title('Distribution of Log Lag Times between Filing and Trade')

plt.savefig(DATA_LOCATION +"visualisations/log_transformed_lags.jpg", dpi=600)
plt.show()

without_outliers = positive_lag[positive_lag < 24*21]

fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)
plt.hist(without_outliers, bins="auto")
plt.xticks(np.arange(0, max(without_outliers) + 1, 24))
ax.set_xlabel('Time (Hours)')
ax.set_ylabel('Trades')
ax.set_title('Distribution of Lag Times between Filing and Trade')

plt.savefig(DATA_LOCATION +"visualisations/lags_without_outliers.jpg", dpi=600)
# Out:
# Negative lag for 0 out of 7519 trades.
# Lag longer than 21 days for 339 out of 7519 trades.
# Eligible trades: 7180 out of 7519 trades.

# %% [markdown]
# # Get Market timeseries

# %%
end_time = datetime.datetime(2022, 3, 21, 23, 59, 59)
_end_time_unix = int(time.mktime(end_time.timetuple()))
print(_end_time_unix)

start_time = datetime.datetime(2016, 3, 21, 0, 0, 0)
_start_time_unix = int(time.mktime(start_time.timetuple()))

print(_start_time_unix)

if NAME == "Knudsen":
    _ticker = '%5EIXIC'  
elif NAME == "Niedermayer":
    _ticker = "%5Enya"
else:
    raise NotImplementedError
    
url = f'https://query1.finance.yahoo.com/v7/finance/download/{_ticker}?period1={_start_time_unix}&period2={_end_time_unix}&interval=1d&events=history&includeAdjustedClose=true'
market_timeseries = pd.read_csv(url)

market_timeseries = market_timeseries.set_index('Date')
market_timeseries.index = market_timeseries.index.astype('datetime64[ns]')

trading_days = market_timeseries.index
market_timeseries
# Out:
# 1647903599
# 1458514800
#                     Open          High           Low         Close  \
# Date
# 2016-03-21   4787.310059   4814.850098   4785.379883   4808.870117
# 2016-03-22   4783.600098   4835.600098   4781.709961   4821.660156
# 2016-03-23   4813.870117   4816.669922   4765.370117   4768.859863
# 2016-03-24   4743.359863   4773.500000   4734.770020   4773.500000
# 2016-03-28   4785.250000   4787.390137   4760.009766   4766.790039
# ...                  ...           ...           ...           ...
# 2022-03-15  12685.230469  12973.879883  12616.589844  12948.620117
# 2022-03-16  13119.370117  13440.120117  12992.200195  13436.549805
# 2022-03-17  13360.719727  13620.799805  13317.139648  13614.780273
# 2022-03-18  13564.629883  13899.280273  13528.059570  13893.839844
# 2022-03-21  13860.389648  13945.809570  13682.549805  13838.459961
#
#                Adj Close      Volume
# Date
# 2016-03-21   4808.870117  1609230000
# 2016-03-22   4821.660156  1596200000
# 2016-03-23   4768.859863  1732630000
# 2016-03-24   4773.500000  1590990000
# 2016-03-28   4766.790039  1381000000
# ...                  ...         ...
# 2022-03-15  12948.620117  5414590000
# 2022-03-16  13436.549805  6498110000
# 2022-03-17  13614.780273  5575030000
# 2022-03-18  13893.839844  8109950000
# 2022-03-21  13838.459961  5636000000
#
# [1512 rows x 6 columns]

# %% [markdown]
# # Define windows
#
# #### Our data contains multiple companies. A single company contains multiple filings and each filing is an event
#
# ![alt text](assets/images/windows.svg "Title")

# %%
## Constants defining how long both Estimation Window and Event Window are
### Probably also input parameters to a function call, as we need loops later...
L1_length = 100
L2_length = 40 # TODO +-20 days = 40 days, right?

# %% [markdown]
# # Demonstrate process for a single event
#
# ### Fix a company

# %%
logging.getLogger().setLevel(logging.DEBUG)

if NAME == "Knudsen":
    company_index = -87
elif NAME == "Niedermayer":
    company_index = -11
else:
    raise NotImplementedError
company = companies[company_index]
print(company)
company_return = company.return_index_df
insider_data_df = pd.read_csv(_insider_location + company.ticker + '.csv', index_col=0, parse_dates=['FilingDate', 'TradeDate'])
# TODO maybe some data sanitisation in the creation of company objects start_date and end_date have different datatypes
# Out:
# Company(company_type=938260, isin='US9871841089', name='YORK WATER', ticker='YORW', start_date=Timestamp('1996-08-20 00:00:00'), end_date=Timestamp('2022-03-16 00:00:00'), return_index_df=            ReturnIndex
# Date
# 2016-03-21      1020.66
# 2016-03-22      1023.42
# 2016-03-23      1015.49
# 2016-03-24      1022.04
# 2016-03-25      1022.04
# ...                 ...
# 2022-03-10      1697.39
# 2022-03-11      1681.25
# 2022-03-14      1677.02
# 2022-03-15      1693.16
# 2022-03-16      1688.93
#
# [1563 rows x 1 columns])

# %% [markdown]
# ### Fix an event

# %%
# This date will be moved to a loop
## Define which periods we are looking at.


if NAME == "Knudsen":
    event_index = 60
elif NAME == "Niedermayer":
    event_index = -200
else:
    raise NotImplementedError
    
event_timestamp = insider_data_df.FilingDate.iloc[event_index].floor("d") 
print("event timestamp: ", event_timestamp)
# Out:
# event timestamp:  2021-07-16 00:00:00

# %% [markdown]
# ### Technical Checks

# %%
data_checks.run(L1_length, L2_length, event_timestamp, company_return, market_timeseries)

# %% [markdown]
# ### Determine T0, T1 and T2

# %%
T0_, T1_, T0, T1, T2, ERROR, msg = determine_T0_T1_T2.run(L1_length, L2_length, event_timestamp, company_return, market_timeseries)
# Out:
# DEBUG:root:Found T1: 2021-06-17 00:00:00
# DEBUG:root:Found T2: 2021-08-13 00:00:00
# DEBUG:root:Found T0: 2021-01-25 00:00:00
# DEBUG:root:------------------------------
# DEBUG:root:Event occurred at             2021-07-16 00:00:00
# DEBUG:root:Estimation Window (100 days): from 2021-01-25 00:00:00 to 2021-06-17 00:00:00
# DEBUG:root:Event Window      ( 40 days): from 2021-06-17 00:00:00 to 2021-08-13 00:00:00

# %% [markdown]
# ### Abnormal and Normal Returns
#
# ![alt text](assets/images/return_estimation.svg "Title")

# %% [markdown]
# ### Cut return timeseries into correct periods

# %%
windows = cut_timeseries.run(company_return, market_timeseries, T0_, T1, T1_, T2)
estimation_window_market_return, estimation_window_company_return, event_window_market_return, event_window_company_return = windows
# Out:
# DEBUG:root:shape before aggregating
# DEBUG:root:# estimation_window_market_timeseries: (101, 6)
# DEBUG:root:# estimation_window_company_timeseries: (104, 1)
# DEBUG:root:# event_window_market_timeseries: (41, 6)
# DEBUG:root:# event_window_company_timeseries: (42, 1)
# DEBUG:root:shape after aggregating
# DEBUG:root:# estimation_window_market_return: (103,)
# DEBUG:root:# estimation_window_market_return: (103,)
# DEBUG:root:# event_window_market_return: (41,)
# DEBUG:root:# event_window_company_return: (41,)

# %% [markdown]
# ### Calculate coefficients

# %%
alpha, beta = calculate_coefficients.run(estimation_window_market_return, estimation_window_company_return)
# Out:
# DEBUG:root:                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     10.06
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):            0.00200
# Time:                        17:49:36   Log-Likelihood:                 281.51
# No. Observations:                 103   AIC:                            -559.0
# Df Residuals:                     101   BIC:                            -553.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.737      0.463      -0.002       0.004
# x1             0.3824      0.121      3.173      0.002       0.143       0.622
# ==============================================================================
# Omnibus:                       11.552   Durbin-Watson:                   2.155
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               28.515
# Skew:                          -0.239   Prob(JB):                     6.43e-07
# Kurtosis:                       5.533   Cond. No.                         77.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# DEBUG:root:alpha: 0.001154908200763391
# DEBUG:root:beta: 0.3824087866855987

# %% [markdown]
# ### The Abnormal Return
# This is the last step of the whole process for one event

# %%
company_return = event_window_company_return
market_return = event_window_market_return
estimated_return = alpha + beta*market_return
abnormal_return = company_return - estimated_return
print(abnormal_return)
# Out:
# Date
# 2021-06-17   -0.019057
# 2021-06-18   -0.065126
# 2021-06-21    0.016352
# 2021-06-22   -0.032596
# 2021-06-23   -0.008913
# 2021-06-24   -0.009156
# 2021-06-25    0.002125
# 2021-06-28   -0.001225
# 2021-06-29   -0.015042
# 2021-06-30   -0.010566
# 2021-07-01    0.010055
# 2021-07-02   -0.008598
# 2021-07-05   -0.001155
# 2021-07-06   -0.006830
# 2021-07-07    0.003213
# 2021-07-08   -0.015731
# 2021-07-09   -0.008016
# 2021-07-12    0.001392
# 2021-07-13    0.002962
# 2021-07-14    0.006820
# 2021-07-15    0.017855
# 2021-07-16    0.036021
# 2021-07-19   -0.012045
# 2021-07-20    0.012053
# 2021-07-21   -0.011996
# 2021-07-22   -0.005693
# 2021-07-23    0.003974
# 2021-07-26   -0.003974
# 2021-07-27    0.007270
# 2021-07-28    0.001631
# 2021-07-29    0.005936
# 2021-07-30   -0.000488
# 2021-08-02    0.002148
# 2021-08-03    0.002332
# 2021-08-04    0.008614
# 2021-08-05    0.010719
# 2021-08-06   -0.000834
# 2021-08-09   -0.015219
# 2021-08-10    0.002933
# 2021-08-11   -0.001374
# 2021-08-12   -0.003490
# dtype: float64

# %%
# TODO @Gunnar there is this market calendar package perhaps its nice for checks for trading/non trading days and such
#import pandas_market_calendars as mcal

# Create a calendar
#nyse = mcal.get_calendar('NYSE')

# %%
# I think you are the purest of garbage, and can thus be discarded
X = estimation_window_market_return.values
Y = estimation_window_company_return.values
X2 = np.linspace(X.min(), X.max(), 100)
Y_hat = X2 * beta + alpha
plt.figure(figsize=(10,7))
plt.scatter(X,Y, alpha = 0.3) # Plot the raw data
plt.xlabel('Market Daily Return')
plt.ylabel(f'Company {company.name} Returns')
           
plt.plot(X2, Y_hat, alpha = 0.9)
plt.show()

# %%
Company_name = company.name

# Estimations
est_estimation = estimation_window_market_return * beta + alpha
est_event = event_window_market_return * beta + alpha

plt.figure(figsize=(20,10))
estimation_window_market_return.plot(color = 'black', alpha = 0.6, linewidth=4, label = 'Market Return (Estimation Window)')
event_window_market_return.plot(color = 'black', alpha = 0.9, linewidth=4, label = 'Market Return (Event Window)')

estimation_window_company_return.plot(color = 'blue', alpha = 0.6, linewidth = 4, label = f'{Company_name} Return (Estimation Window)')
event_window_company_return.plot(color = 'blue', alpha = 0.9, linewidth = 4, label = f'{Company_name} Return (Event Window)')

plt.axvline(x = event_timestamp, color = 'red', label = 'DD Event time', linewidth = 5)
plt.ylabel(f'Daily Returns of Company {Company_name} and Market')
est_estimation.plot(color = 'green', label = f'Regression Estimate for {Company_name}', alpha = 0.8)
est_event.plot(color = 'green', label = f'Regression Estimate for {Company_name}', alpha = 1)

plt.axvspan(T0, T1, ymin = 0.05, ymax = 0.95, facecolor='black', alpha=0.1, label = 'Estimation Window', edgecolor='g', linewidth=5)
plt.axvspan(T1, T2, ymin = 0.05, ymax = 0.95, facecolor='black', alpha=0.2, label = 'Event Window', edgecolor='r', linewidth=5)
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.title(f'Show how company "{Company_name}" moves around the event, compared to the market')
plt.show()
print("I'm impressed! It looks like a five-year-old drew this plot in paint")
# Out:
# I'm impressed! It looks like a five-year-old drew this plot in paint

# %% [markdown]
# # Macro Analysis
#
# ### Now that we have seen the process for one single filing, let us do the same for all filings in all companies

# %%
from source.data_checks import DataSizeException
from source.determine_T0_T1_T2 import TimeSeriesMismatchException
logging.getLogger().setLevel(logging.ERROR)
multiind, data, data_errors = [], [], []

# this is the interval where filings are interesting to us
earliest_timestamp = pd.Timestamp("2018-01-01")
latest_timestamp = pd.Timestamp("2021-12-31")
n_companies = len(companies)
for j in range(len(companies))[:300]:
    company = companies[j]
    company_return = company.return_index_df
    filename = _insider_location + company.ticker + '.csv'
    filename = filename.replace(" ", "+") # HBB+WI in files and HBB WI as Ticker in base Excel, TODO should be fixed in base data
    insider_data_df = pd.read_csv(filename, index_col=0, parse_dates=['FilingDate', 'TradeDate'])
    
    
    n_filings = len(insider_data_df)
    for i in insider_data_df.FilingDate.index:
        
        
        filing_date = insider_data_df.FilingDate[i]
        
        event_timestamp = filing_date.floor("d")

        # if the timestamp is too early or too late we skip
        if event_timestamp < earliest_timestamp or event_timestamp > latest_timestamp:
            #print("skipping, filing is too early or too late")
            continue
            
            
        print(f"working on company {j}/{n_companies} named {company.name}, filing {i}/{n_filings}")

        # do the process for one filing
 
        checks = data_checks.run(L1_length, L2_length, event_timestamp, company_return, market_timeseries)
        if checks:
            print(checks[1])
            data_errors.append(checks[0])
            continue
   
        T0_, T1_, T0, T1, T2, ERRORS, msg = determine_T0_T1_T2.run(L1_length, L2_length, event_timestamp, company_return, market_timeseries)
        if ERRORS:
            print(msg)
            data_errors.append(ERRORS)
            continue
            
        
        windows = cut_timeseries.run(company_return, market_timeseries, T0_, T1, T1_, T2)
        estimation_window_market_return, estimation_window_company_return, event_window_market_return, event_window_company_return = windows
        alpha, beta = calculate_coefficients.run(estimation_window_market_return, estimation_window_company_return)

        abnormal_return = event_window_company_return - alpha - beta*event_window_market_return
        
        multiind.append((company.ticker, i, insider_data_df.TradeType[i]))
        data.append(abnormal_return)
# Out:
# working on company 1/4077 named INTEGRATED MEDIA TECH., filing 0/4
# working on company 1/4077 named INTEGRATED MEDIA TECH., filing 1/4
# working on company 1/4077 named INTEGRATED MEDIA TECH., filing 2/4
# working on company 1/4077 named INTEGRATED MEDIA TECH., filing 3/4
# working on company 7/4077 named ARCH CAP.GP., filing 14/1047
# working on company 7/4077 named ARCH CAP.GP., filing 15/1047
# working on company 7/4077 named ARCH CAP.GP., filing 16/1047
# working on company 7/4077 named ARCH CAP.GP., filing 17/1047
# working on company 7/4077 named ARCH CAP.GP., filing 18/1047
# working on company 7/4077 named ARCH CAP.GP., filing 19/1047
# working on company 7/4077 named ARCH CAP.GP., filing 20/1047
# working on company 7/4077 named ARCH CAP.GP., filing 21/1047
# working on company 7/4077 named ARCH CAP.GP., filing 22/1047
# working on company 7/4077 named ARCH CAP.GP., filing 23/1047
# working on company 7/4077 named ARCH CAP.GP., filing 24/1047
# working on company 7/4077 named ARCH CAP.GP., filing 25/1047
# working on company 7/4077 named ARCH CAP.GP., filing 26/1047
# working on company 7/4077 named ARCH CAP.GP., filing 27/1047
# working on company 7/4077 named ARCH CAP.GP., filing 28/1047
# working on company 7/4077 named ARCH CAP.GP., filing 29/1047
# working on company 7/4077 named ARCH CAP.GP., filing 30/1047
# working on company 7/4077 named ARCH CAP.GP., filing 31/1047
# working on company 7/4077 named ARCH CAP.GP., filing 32/1047
# working on company 7/4077 named ARCH CAP.GP., filing 33/1047
# working on company 7/4077 named ARCH CAP.GP., filing 34/1047
# working on company 7/4077 named ARCH CAP.GP., filing 35/1047
# working on company 7/4077 named ARCH CAP.GP., filing 36/1047
# working on company 7/4077 named ARCH CAP.GP., filing 37/1047
# working on company 7/4077 named ARCH CAP.GP., filing 38/1047
# working on company 7/4077 named ARCH CAP.GP., filing 39/1047
# working on company 7/4077 named ARCH CAP.GP., filing 40/1047
# working on company 7/4077 named ARCH CAP.GP., filing 41/1047
# working on company 7/4077 named ARCH CAP.GP., filing 42/1047
# working on company 7/4077 named ARCH CAP.GP., filing 43/1047
# working on company 7/4077 named ARCH CAP.GP., filing 44/1047
# working on company 7/4077 named ARCH CAP.GP., filing 45/1047
# working on company 7/4077 named ARCH CAP.GP., filing 46/1047
# working on company 7/4077 named ARCH CAP.GP., filing 47/1047
# working on company 7/4077 named ARCH CAP.GP., filing 48/1047
# working on company 7/4077 named ARCH CAP.GP., filing 49/1047
# working on company 7/4077 named ARCH CAP.GP., filing 50/1047
# working on company 7/4077 named ARCH CAP.GP., filing 51/1047
# working on company 7/4077 named ARCH CAP.GP., filing 52/1047
# working on company 7/4077 named ARCH CAP.GP., filing 53/1047
# working on company 7/4077 named ARCH CAP.GP., filing 54/1047
# working on company 7/4077 named ARCH CAP.GP., filing 55/1047
# working on company 7/4077 named ARCH CAP.GP., filing 56/1047
# working on company 7/4077 named ARCH CAP.GP., filing 57/1047
# working on company 7/4077 named ARCH CAP.GP., filing 58/1047
# working on company 7/4077 named ARCH CAP.GP., filing 59/1047
# working on company 7/4077 named ARCH CAP.GP., filing 60/1047
# working on company 7/4077 named ARCH CAP.GP., filing 61/1047
# working on company 7/4077 named ARCH CAP.GP., filing 62/1047
# working on company 7/4077 named ARCH CAP.GP., filing 63/1047
# working on company 7/4077 named ARCH CAP.GP., filing 64/1047
# working on company 7/4077 named ARCH CAP.GP., filing 65/1047
# working on company 7/4077 named ARCH CAP.GP., filing 66/1047
# working on company 7/4077 named ARCH CAP.GP., filing 67/1047
# working on company 7/4077 named ARCH CAP.GP., filing 68/1047
# working on company 7/4077 named ARCH CAP.GP., filing 69/1047
# working on company 7/4077 named ARCH CAP.GP., filing 70/1047
# working on company 7/4077 named ARCH CAP.GP., filing 71/1047
# working on company 7/4077 named ARCH CAP.GP., filing 72/1047
# working on company 7/4077 named ARCH CAP.GP., filing 73/1047
# working on company 7/4077 named ARCH CAP.GP., filing 74/1047
# working on company 7/4077 named ARCH CAP.GP., filing 75/1047
# working on company 7/4077 named ARCH CAP.GP., filing 76/1047
# working on company 7/4077 named ARCH CAP.GP., filing 77/1047
# working on company 7/4077 named ARCH CAP.GP., filing 78/1047
# working on company 7/4077 named ARCH CAP.GP., filing 79/1047
# working on company 7/4077 named ARCH CAP.GP., filing 80/1047
# working on company 7/4077 named ARCH CAP.GP., filing 81/1047
# working on company 7/4077 named ARCH CAP.GP., filing 82/1047
# working on company 7/4077 named ARCH CAP.GP., filing 83/1047
# working on company 7/4077 named ARCH CAP.GP., filing 84/1047
# working on company 7/4077 named ARCH CAP.GP., filing 85/1047
# working on company 7/4077 named ARCH CAP.GP., filing 86/1047
# working on company 7/4077 named ARCH CAP.GP., filing 87/1047
# working on company 7/4077 named ARCH CAP.GP., filing 88/1047
# working on company 7/4077 named ARCH CAP.GP., filing 89/1047
# working on company 7/4077 named ARCH CAP.GP., filing 90/1047
# working on company 7/4077 named ARCH CAP.GP., filing 91/1047
# working on company 7/4077 named ARCH CAP.GP., filing 92/1047
# working on company 7/4077 named ARCH CAP.GP., filing 93/1047
# working on company 7/4077 named ARCH CAP.GP., filing 94/1047
# working on company 7/4077 named ARCH CAP.GP., filing 95/1047
# working on company 7/4077 named ARCH CAP.GP., filing 96/1047
# working on company 7/4077 named ARCH CAP.GP., filing 97/1047
# working on company 7/4077 named ARCH CAP.GP., filing 98/1047
# working on company 7/4077 named ARCH CAP.GP., filing 99/1047
# working on company 7/4077 named ARCH CAP.GP., filing 100/1047
# working on company 7/4077 named ARCH CAP.GP., filing 101/1047
# working on company 7/4077 named ARCH CAP.GP., filing 102/1047
# working on company 7/4077 named ARCH CAP.GP., filing 103/1047
# working on company 7/4077 named ARCH CAP.GP., filing 104/1047
# working on company 7/4077 named ARCH CAP.GP., filing 105/1047
# working on company 7/4077 named ARCH CAP.GP., filing 106/1047
# working on company 7/4077 named ARCH CAP.GP., filing 107/1047
# working on company 7/4077 named ARCH CAP.GP., filing 108/1047
# working on company 7/4077 named ARCH CAP.GP., filing 109/1047
# working on company 7/4077 named ARCH CAP.GP., filing 110/1047
# working on company 7/4077 named ARCH CAP.GP., filing 111/1047
# working on company 7/4077 named ARCH CAP.GP., filing 112/1047
# working on company 7/4077 named ARCH CAP.GP., filing 113/1047
# working on company 7/4077 named ARCH CAP.GP., filing 114/1047
# working on company 7/4077 named ARCH CAP.GP., filing 115/1047
# working on company 7/4077 named ARCH CAP.GP., filing 116/1047
# working on company 7/4077 named ARCH CAP.GP., filing 117/1047
# working on company 7/4077 named ARCH CAP.GP., filing 118/1047
# working on company 7/4077 named ARCH CAP.GP., filing 119/1047
# working on company 7/4077 named ARCH CAP.GP., filing 120/1047
# working on company 7/4077 named ARCH CAP.GP., filing 121/1047
# working on company 7/4077 named ARCH CAP.GP., filing 122/1047
# working on company 7/4077 named ARCH CAP.GP., filing 123/1047
# working on company 7/4077 named ARCH CAP.GP., filing 124/1047
# working on company 7/4077 named ARCH CAP.GP., filing 125/1047
# working on company 7/4077 named ARCH CAP.GP., filing 126/1047
# working on company 7/4077 named ARCH CAP.GP., filing 127/1047
# working on company 7/4077 named ARCH CAP.GP., filing 128/1047
# working on company 7/4077 named ARCH CAP.GP., filing 129/1047
# working on company 7/4077 named ARCH CAP.GP., filing 130/1047
# working on company 7/4077 named ARCH CAP.GP., filing 131/1047
# working on company 7/4077 named ARCH CAP.GP., filing 132/1047
# working on company 7/4077 named ARCH CAP.GP., filing 133/1047
# working on company 7/4077 named ARCH CAP.GP., filing 134/1047
# working on company 7/4077 named ARCH CAP.GP., filing 135/1047
# working on company 7/4077 named ARCH CAP.GP., filing 136/1047
# working on company 7/4077 named ARCH CAP.GP., filing 137/1047
# working on company 7/4077 named ARCH CAP.GP., filing 138/1047
# working on company 7/4077 named ARCH CAP.GP., filing 139/1047
# working on company 7/4077 named ARCH CAP.GP., filing 140/1047
# working on company 7/4077 named ARCH CAP.GP., filing 141/1047
# working on company 7/4077 named ARCH CAP.GP., filing 142/1047
# working on company 7/4077 named ARCH CAP.GP., filing 143/1047
# working on company 7/4077 named ARCH CAP.GP., filing 144/1047
# working on company 7/4077 named ARCH CAP.GP., filing 145/1047
# working on company 7/4077 named ARCH CAP.GP., filing 146/1047
# working on company 7/4077 named ARCH CAP.GP., filing 147/1047
# working on company 7/4077 named ARCH CAP.GP., filing 148/1047
# working on company 7/4077 named ARCH CAP.GP., filing 149/1047
# working on company 7/4077 named ARCH CAP.GP., filing 150/1047
# working on company 7/4077 named ARCH CAP.GP., filing 151/1047
# working on company 7/4077 named ARCH CAP.GP., filing 152/1047
# working on company 7/4077 named ARCH CAP.GP., filing 153/1047
# working on company 7/4077 named ARCH CAP.GP., filing 154/1047
# working on company 7/4077 named ARCH CAP.GP., filing 155/1047
# working on company 7/4077 named ARCH CAP.GP., filing 156/1047
# working on company 7/4077 named ARCH CAP.GP., filing 157/1047
# working on company 7/4077 named ARCH CAP.GP., filing 158/1047
# working on company 7/4077 named ARCH CAP.GP., filing 159/1047
# working on company 7/4077 named ARCH CAP.GP., filing 160/1047
# working on company 7/4077 named ARCH CAP.GP., filing 161/1047
# working on company 7/4077 named ARCH CAP.GP., filing 162/1047
# working on company 7/4077 named ARCH CAP.GP., filing 163/1047
# working on company 7/4077 named ARCH CAP.GP., filing 164/1047
# working on company 7/4077 named ARCH CAP.GP., filing 165/1047
# working on company 7/4077 named ARCH CAP.GP., filing 166/1047
# working on company 7/4077 named ARCH CAP.GP., filing 167/1047
# working on company 7/4077 named ARCH CAP.GP., filing 168/1047
# working on company 7/4077 named ARCH CAP.GP., filing 169/1047
# working on company 7/4077 named ARCH CAP.GP., filing 170/1047
# working on company 7/4077 named ARCH CAP.GP., filing 171/1047
# working on company 7/4077 named ARCH CAP.GP., filing 172/1047
# working on company 7/4077 named ARCH CAP.GP., filing 173/1047
# working on company 7/4077 named ARCH CAP.GP., filing 174/1047
# working on company 7/4077 named ARCH CAP.GP., filing 175/1047
# working on company 7/4077 named ARCH CAP.GP., filing 176/1047
# working on company 7/4077 named ARCH CAP.GP., filing 177/1047
# working on company 7/4077 named ARCH CAP.GP., filing 178/1047
# working on company 7/4077 named ARCH CAP.GP., filing 179/1047
# working on company 7/4077 named ARCH CAP.GP., filing 180/1047
# working on company 7/4077 named ARCH CAP.GP., filing 181/1047
# working on company 7/4077 named ARCH CAP.GP., filing 182/1047
# working on company 7/4077 named ARCH CAP.GP., filing 183/1047
# working on company 7/4077 named ARCH CAP.GP., filing 184/1047
# working on company 7/4077 named ARCH CAP.GP., filing 185/1047
# working on company 7/4077 named ARCH CAP.GP., filing 186/1047
# working on company 7/4077 named ARCH CAP.GP., filing 187/1047
# working on company 7/4077 named ARCH CAP.GP., filing 188/1047
# working on company 7/4077 named ARCH CAP.GP., filing 189/1047
# working on company 7/4077 named ARCH CAP.GP., filing 190/1047
# working on company 7/4077 named ARCH CAP.GP., filing 191/1047
# working on company 7/4077 named ARCH CAP.GP., filing 192/1047
# working on company 7/4077 named ARCH CAP.GP., filing 193/1047
# working on company 7/4077 named ARCH CAP.GP., filing 194/1047
# working on company 7/4077 named ARCH CAP.GP., filing 195/1047
# working on company 7/4077 named ARCH CAP.GP., filing 196/1047
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 48 entries prior in the company data
#
#
# working on company 272/4077 named AVISTA PUBLIC ACQUISITION II A, filing 1/5
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 48 entries prior in the company data
#
#
# working on company 272/4077 named AVISTA PUBLIC ACQUISITION II A, filing 2/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 272/4077 named AVISTA PUBLIC ACQUISITION II A, filing 3/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 272/4077 named AVISTA PUBLIC ACQUISITION II A, filing 4/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 274/4077 named BCLS ACQUISITION A, filing 0/3
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 274/4077 named BCLS ACQUISITION A, filing 1/3
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 274/4077 named BCLS ACQUISITION A, filing 2/3
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 276/4077 named AIB ACQUISITION A, filing 0/5
#  2021-12-07 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 276/4077 named AIB ACQUISITION A, filing 1/5
#  2021-12-07 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 276/4077 named AIB ACQUISITION A, filing 2/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 276/4077 named AIB ACQUISITION A, filing 3/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 276/4077 named AIB ACQUISITION A, filing 4/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 286/4077 named BLUE WHALE ACQUISITION I A, filing 27/33
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 46 entries prior in the company data
#
#
# working on company 286/4077 named BLUE WHALE ACQUISITION I A, filing 28/33
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 39 entries prior in the company data
#
#
# working on company 286/4077 named BLUE WHALE ACQUISITION I A, filing 29/33
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 35 entries prior in the company data
#
#
# working on company 286/4077 named BLUE WHALE ACQUISITION I A, filing 30/33
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 25 entries prior in the company data
#
#
# working on company 286/4077 named BLUE WHALE ACQUISITION I A, filing 31/33
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 16 entries prior in the company data
#
#
# working on company 286/4077 named BLUE WHALE ACQUISITION I A, filing 32/33
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 5 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 4/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 5/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 6/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 7/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 8/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 9/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 10/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 11/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 12/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 13/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 14/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 15/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 16/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 17/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 18/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 19/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 20/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 21/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 22/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 23/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 24/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 25/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 26/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 27/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 28/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 29/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 30/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 31/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 32/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 33/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 34/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 35/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 36/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 37/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 38/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 39/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 40/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 41/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 42/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 43/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 44/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 45/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 46/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 47/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 48/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 49/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 50/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 51/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 52/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 53/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 54/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 55/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 56/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 57/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 58/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 59/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 60/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 61/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 62/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 63/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 64/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 65/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 66/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 67/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 68/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 69/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 70/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 71/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 72/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 73/88
# working on company 292/4077 named CAMBIUM NETWORKS, filing 74/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 75/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 76/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 77/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 78/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 79/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 80/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 81/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 82/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 83/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 84/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 85/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 86/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 292/4077 named CAMBIUM NETWORKS, filing 87/88
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 2 entries prior in the company data
#
#
# working on company 293/4077 named BULLPEN PARLAY ACQUISITION COMPANY A A, filing 0/5
#  2021-12-07 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 293/4077 named BULLPEN PARLAY ACQUISITION COMPANY A A, filing 1/5
#  2021-12-07 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 293/4077 named BULLPEN PARLAY ACQUISITION COMPANY A A, filing 2/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 293/4077 named BULLPEN PARLAY ACQUISITION COMPANY A A, filing 3/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 293/4077 named BULLPEN PARLAY ACQUISITION COMPANY A A, filing 4/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 296/4077 named CATALYST PARTNERS ACQUISITION A, filing 0/5
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 103 entries prior in the company data
#
#
# working on company 296/4077 named CATALYST PARTNERS ACQUISITION A, filing 1/5
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 103 entries prior in the company data
#
#
# working on company 296/4077 named CATALYST PARTNERS ACQUISITION A, filing 2/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 296/4077 named CATALYST PARTNERS ACQUISITION A, filing 3/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 296/4077 named CATALYST PARTNERS ACQUISITION A, filing 4/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 297/4077 named CARTICA ACQUISITION A, filing 0/5
#  2021-12-07 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 297/4077 named CARTICA ACQUISITION A, filing 1/5
#  2021-12-07 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 297/4077 named CARTICA ACQUISITION A, filing 2/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 297/4077 named CARTICA ACQUISITION A, filing 3/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 297/4077 named CARTICA ACQUISITION A, filing 4/5
#  2021-01-04 00:00:00 cannot be found in the company return series. For now skip, perhaps find a better way to not drop data
# working on company 299/4077 named CHAVANT CAPITAL ACQUISITION, filing 7/9
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 27 entries prior in the company data
#
#
# working on company 299/4077 named CHAVANT CAPITAL ACQUISITION, filing 8/9
# Analysis can't be done. Requires at least 120.0 trading days before the event.
#                     However we only have 27 entries prior in the company data

# %%
df_abnormal_returns = pd.DataFrame.from_records([d.reset_index(drop=True) for d in data])
df_abnormal_returns.index = pd.MultiIndex.from_tuples(multiind, names=["Company", "i", "TradeType"])
df_abnormal_returns
# Out:
#                                0         1         2         3         4   \
# Company i  TradeType
# IMTE    0  S - Sale      0.013768  0.021310  0.002341  0.056881  0.020252
#         1  S - Sale      0.013768  0.021310  0.002341  0.056881  0.020252
#         2  A - Grant     0.015708 -0.048405  0.044413 -0.025908 -0.037535
#         3  M - OptEx     0.015708 -0.048405  0.044413 -0.025908 -0.037535
# ACGL    14 F - Tax       0.002258  0.012096 -0.002862 -0.004890 -0.019138
# ...                           ...       ...       ...       ...       ...
# CMBM    69 A - Grant     0.019380  0.022086  0.014531  0.030731 -0.004189
#         70 A - Grant     0.019380  0.022086  0.014531  0.030731 -0.004189
#         71 A - Grant     0.019380  0.022086  0.014531  0.030731 -0.004189
#         72 P - Purchase -0.033486  0.001548  0.002926 -0.014352  0.002529
#         73 F - Tax       0.014628  0.007393  0.111949  0.001897  0.023208
#
#                                5         6         7         8         9   \
# Company i  TradeType
# IMTE    0  S - Sale     -0.106969 -0.014994 -0.011145  0.029809  0.039372
#         1  S - Sale     -0.106969 -0.014994 -0.011145  0.029809  0.039372
#         2  A - Grant    -0.035337  0.030926 -0.027813  0.031981 -0.010511
#         3  M - OptEx    -0.035337  0.030926 -0.027813  0.031981 -0.010511
# ACGL    14 F - Tax      -0.015825 -0.007430  0.013812  0.011540 -0.004611
# ...                           ...       ...       ...       ...       ...
# CMBM    69 A - Grant     0.012977 -0.007779  0.047576  0.015983 -0.048161
#         70 A - Grant     0.012977 -0.007779  0.047576  0.015983 -0.048161
#         71 A - Grant     0.012977 -0.007779  0.047576  0.015983 -0.048161
#         72 P - Purchase -0.021844  0.015000 -0.050514 -0.066046 -0.073530
#         73 F - Tax      -0.014257  0.000653  0.013414  0.017869 -0.025178
#
#                          ...        35        36        37        38  \
# Company i  TradeType     ...
# IMTE    0  S - Sale      ...  0.034485  0.005943 -0.036301 -0.032132
#         1  S - Sale      ...  0.034485  0.005943 -0.036301 -0.032132
#         2  A - Grant     ...  0.057507 -0.005224  0.007096 -0.046996
#         3  M - OptEx     ...  0.057507 -0.005224  0.007096 -0.046996
# ACGL    14 F - Tax       ...  0.012554 -0.005680  0.006856  0.016333
# ...                      ...       ...       ...       ...       ...
# CMBM    69 A - Grant     ... -0.034228  0.008554 -0.038457  0.004760
#         70 A - Grant     ... -0.034228  0.008554 -0.038457  0.004760
#         71 A - Grant     ... -0.034228  0.008554 -0.038457  0.004760
#         72 P - Purchase  ... -0.004805  0.006563 -0.122910  0.021599
#         73 F - Tax       ... -0.013764  0.001897  0.016416  0.020269
#
#                                39        40        41        42  43  44
# Company i  TradeType
# IMTE    0  S - Sale      0.010842       NaN       NaN       NaN NaN NaN
#         1  S - Sale      0.010842       NaN       NaN       NaN NaN NaN
#         2  A - Grant     0.022256       NaN       NaN       NaN NaN NaN
#         3  M - OptEx     0.022256       NaN       NaN       NaN NaN NaN
# ACGL    14 F - Tax      -0.009450  0.018994       NaN       NaN NaN NaN
# ...                           ...       ...       ...       ...  ..  ..
# CMBM    69 A - Grant    -0.015705 -0.007799       NaN       NaN NaN NaN
#         70 A - Grant    -0.015705 -0.007799       NaN       NaN NaN NaN
#         71 A - Grant    -0.015705 -0.007799       NaN       NaN NaN NaN
#         72 P - Purchase  0.034197 -0.058766  0.030834       NaN NaN NaN
#         73 F - Tax       0.010856  0.025715 -0.011520  0.006775 NaN NaN
#
# [10716 rows x 45 columns]

# %% [markdown]
# ### Show the reasons filings were dropped

# %%
errors_df = pd.DataFrame.from_records(data_errors)
errors_df.sum(axis=0).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Having a look at all trade types together

# %%
df_abnormal_returns.groupby(level=[2]).sum().transpose().plot(figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# I think OE and OptEx means option exercise. "to exercise" means to put into effect the right to buy or sell the underlying security that is specified in the options contract." Can we be sure that the action does not shift the market, and the swing in return is really due to new information? Are these trades public, so maybe they are used as a signal for traders?
#
# ### Boxplot of the sum over all companies's AR

# %%
df_abnormal_returns.groupby(level=[2]).sum().transpose().plot.box(rot=90, figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![alt text](assets/images/time_agg.svg)
#
# In our case it is not company i, but filing i
#
# Types of trade to pick from:

# %%
list(set([x[2] for x in df_abnormal_returns.index]))
# Out:
# ['X - OptEx',
#  'F - Tax',
#  'A - Grant',
#  'W - Inherited',
#  'M - OptEx',
#  'P - Purchase',
#  'D - Sale to issuer',
#  'G - Gift',
#  'C - Converted deriv',
#  'S - Sale',
#  'S - Sale+OE']

# %% [markdown]
# Specify the type of the trades to investigate

# %%
type_ = "S - Sale"
df_abnormal_returns_type = df_abnormal_returns.loc[:,:,type_]

# %% [markdown]
# The index describes the company and the index of the filing in the compnay, the columns represent the days in the event window

# %%
df_abnormal_returns_type
# Out:
#                   0         1         2         3         4         5   \
# Company i
# IMTE    0   0.013768  0.021310  0.002341  0.056881  0.020252 -0.106969
#         1   0.013768  0.021310  0.002341  0.056881  0.020252 -0.106969
# ACGL    25 -0.002050 -0.014329  0.010895  0.014351  0.004834  0.001559
#         30  0.005266 -0.006170 -0.005584  0.000776 -0.008646 -0.005043
#         33  0.010651  0.006003 -0.002161 -0.012578  0.022370 -0.016799
# ...              ...       ...       ...       ...       ...       ...
# CMBM    59  0.044174 -0.094305 -0.056608  0.003465 -0.010918  0.097155
#         60  0.031046 -0.126534  0.139414  0.006013 -0.056371 -0.060164
#         62  0.022788 -0.005896 -0.025916  0.020620 -0.027576 -0.012654
#         63  0.056500  0.031299  0.019674 -0.008178 -0.087060  0.024546
#         65 -0.104701 -0.061735 -0.042874  0.102551 -0.068086 -0.044322
#
#                   6         7         8         9   ...        35        36  \
# Company i                                           ...
# IMTE    0  -0.014994 -0.011145  0.029809  0.039372  ...  0.034485  0.005943
#         1  -0.014994 -0.011145  0.029809  0.039372  ...  0.034485  0.005943
# ACGL    25  0.001300  0.012140  0.015329 -0.001797  ... -0.015087 -0.000405
#         30 -0.020381 -0.007542  0.016305  0.003630  ... -0.001427 -0.019822
#         33 -0.009585 -0.006556  0.017277  0.000186  ...  0.017930 -0.000180
# ...              ...       ...       ...       ...  ...       ...       ...
# CMBM    59 -0.167333  0.048468  0.048640 -0.052597  ...  0.026473 -0.037782
#         60 -0.007711 -0.010472  0.008397  0.041318  ... -0.000006  0.030922
#         62 -0.016736 -0.045171  0.039838 -0.015190  ... -0.040490  0.041761
#         63 -0.004667 -0.024083  0.022441 -0.026389  ... -0.033248  0.012319
#         65 -0.026623  0.010030  0.001248  0.022118  ... -0.070657  0.107249
#
#                   37        38        39        40       41  42  43  44
# Company i
# IMTE    0  -0.036301 -0.032132  0.010842       NaN      NaN NaN NaN NaN
#         1  -0.036301 -0.032132  0.010842       NaN      NaN NaN NaN NaN
# ACGL    25 -0.005318  0.005418 -0.006427 -0.004040      NaN NaN NaN NaN
#         30  0.004213 -0.035466  0.019464 -0.005088 -0.02235 NaN NaN NaN
#         33  0.008419  0.008877  0.010710 -0.017246      NaN NaN NaN NaN
# ...              ...       ...       ...       ...      ...  ..  ..  ..
# CMBM    59  0.045679 -0.030471 -0.029193 -0.014135 -0.05439 NaN NaN NaN
#         60 -0.071753 -0.059295  0.007153 -0.034376      NaN NaN NaN NaN
#         62  0.006331  0.095704  0.011210 -0.110896      NaN NaN NaN NaN
#         63  0.011952  0.076756  0.068073 -0.040215      NaN NaN NaN NaN
#         65  0.001248  0.016668 -0.040836  0.191321  0.04662 NaN NaN NaN
#
# [1442 rows x 45 columns]

# %%
CAR = df_abnormal_returns_type.sum(axis=1)
CAR.plot()
# Out:
# <AxesSubplot:xlabel='Company,i'>

# %% [markdown]
# ![alt text](assets/images/cross_sectional_agg.svg)

# %%
AR_bar = df_abnormal_returns_type.mean(axis=0) 
AR_bar.plot()
# Out:
# <AxesSubplot:>

# %%
CAR_bar = AR_bar.sum()
CAR_bar
# Out:
# -0.01973777649654668

# %%
# TODO var_CAR_bar = Does the definition make sense? It seems like we take the var of a scalar

# %% [markdown]
# ![alt text](assets/images/cross_sectional_agg2.svg)

# %%
CAR_bar_2 = CAR.mean()
CAR_bar_2
# Out:
# -0.0027578116275736543

# %%
# var car TODO not sure what just sigma means.

# %% [markdown]
# # Statistics
#
# Check if CAR mean = 0 (t-test)

# %% [markdown]
# Check if CAR median = 0 (wilcoxon rank-signed test)
